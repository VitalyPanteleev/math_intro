# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(-10, 10, 200)

for k in [1, 2]:
    plt.plot(x, np.cos(k*x), label= f'y = cos(kx), k = {k}')

leg = plt.legend()
plt.xlabel('x')
plt.ylabel('y')
plt.ylim(-2,2) 
plt.grid(True)

plt.show()
